           59.12528887, 59.4866273 , 59.84797322, 60.20932652, 60.57068709,
           60.93205481, 61.2934296 , 61.65481135, 62.01619995, 62.37759532,
           62.73899736, 63.10040597, 63.46182108, 63.82324258, 64.1846704 ,
           64.54610445, 64.90754466, 65.26899094, 65.63044322, 65.99190141,
           66.35336545, 66.71483527, 67.07631079, 67.43779195, 67.79927867,
           68.1607709 , 68.52226857, 68.88377161, 69.24527996, 69.60679357,
           69.96831238, 70.32983632, 70.69136534, 71.05289939, 71.41443841,
           71.77598235, 72.13753116, 72.49908479, 72.86064319, 73.2222063 ,
           73.58377409, 73.9453465 , 74.3069235 , 74.66850503, 75.03009105,
           75.39168152]

x = np.array(x)
y = np.array(y)

# %%
fig, ax = plt.subplots(1, 1)
ax.plot(x, y)
ax.set_xscale('log')
ax.xaxis.set_major_formatter(mpl.ticker.FormatStrFormatter('%g'))

# %%
from scipy.optimize import curve_fit

# def func_QE_term(T_ex, a, b, c, d, e):
#     if isinstance(T_ex, u.Quantity):
#         T_ex = T_ex.cgs.value
#     #return (a * T_ex + b) * (c + d / T_ex**e)
#     return (a * T_ex + b) * (c + d / (T_ex/75.)**e)
#     # [1.41227913e-01, 2.44171545e+00, 2.49370716e+00, 2.21219906e-05, 6.22498729e+00]

# def fit_func_QE_CO(x, y):
#     popt, pcov = curve_fit(func_QE_term, x, y, p0=[0.2, 1.0, 1.0, 1.0, 2.2])
#     yfit = func_QE_term(x, *popt)
#     return popt, yfit

# def func_QE_term(T_ex, a, b, c, d):
#     if isinstance(T_ex, u.Quantity):
#         T_ex = T_ex.cgs.value
#     return (a * T_ex + b) * (c / (T_ex/75.)**d + 1.0)
#     # [3.52180995e-01, 6.08893444e+00, 8.87036438e-06, 6.22502809e+00]

# def fit_func_QE_CO(x, y):
#     popt, pcov = curve_fit(func_QE_term, x, y, p0=[0.2, 1.0, 1e-3, 2.2])
#     yfit = func_QE_term(x, *popt)
#     return popt, yfit

def func_QE_term(T_ex, a, b, c, d):
    if isinstance(T_ex, u.Quantity):
        T_ex = T_ex.cgs.value
    return (a * T_ex + b) * ((T_ex/15.0)**c + d)
    # 

def fit_func_QE_CO(x, y):
    popt, pcov = curve_fit(func_QE_term, x, y, p0=[0.2, 1.0, -2.0, 2.0])
    yfit = func_QE_term(x, *popt)
    return popt, yfit

popt, yfit = fit_func_QE_CO(x, y)

fig, ax = plt.subplots(1, 1)
ax.plot(x, y)
ax.set_xscale('log')
ax.xaxis.set_major_formatter(mpl.ticker.FormatStrFormatter('%g'))
ax.plot(x, yfit, ls='dashed')
print('popt:', repr(popt))
# Out:
# popt: array([ 0.03706622,  0.27593119, -2.07833737,  9.7519126 ])

# %%
from scipy.optimize import curve_fit

def func_QE_term(T_ex, a, b, c, d):
    if isinstance(T_ex, u.Quantity):
        T_ex = T_ex.cgs.value
    return a + b * T_ex + c * np.exp(-T_ex) + d * np.exp(-T_ex**0.5) # * (c / T_ex**d)

def fit_func_QE_CO(x, y):
    popt, pcov = curve_fit(func_QE_term, x, y, p0=[1.0, 1.0, 1.0, 0.2])
    yfit = func_QE_term(x, *popt)
    return popt, yfit

popt, yfit = fit_func_QE_CO(x, y)

fig, ax = plt.subplots(1, 1)
ax.plot(x, y)
ax.set_xscale('log')
ax.xaxis.set_major_formatter(mpl.ticker.FormatStrFormatter('%g'))
ax.plot(x, yfit, ls='dashed')
print('popt:', repr(popt))
# Out:
# popt: array([5.26563207e+00, 3.57872101e-01, 2.86100622e+05, 2.23680277e+02])
